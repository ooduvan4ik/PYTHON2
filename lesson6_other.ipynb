# %%
#1). Загрузите датасет Wine из встроенных датасетов sklearn.datasets с помощью функции load_wine в переменную data.
#2). Полученный датасет не является датафреймом. Это структура данных, имеющая ключи аналогично словарю. 
#Просмотрите тип данных этой структуры данных и создайте список data_keys, содержащий ее ключи.
#3). Просмотрите данные, описание и названия признаков в датасете. Описание нужно вывести в виде привычного, 
#аккуратно оформленного текста, без обозначений переноса строки, но с самими переносами и т.д.4). 
#Сколько классов содержит целевая переменная датасета? Выведите названия классов.

import sklearn.datasets as datasets
import pandas as pd
import numpy as np
wine=datasets.load_wine()
data=wine["data"]
print(type(data))
data_keys=wine.keys()
feature_names = wine["feature_names"]
print(data_keys)
print(feature_names)
#print(data["DESCR"])
# Out:
# <class 'numpy.ndarray'>
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names'])
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']

# %%
pd.pivot_table(y, index=["Class"], aggfunc=np.count_nonzero)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2]

# %%
X = pd.DataFrame(data, columns=feature_names)
print(X.head(10))
data.shape
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
# 5    14.20        1.76  2.45               15.2      112.0           3.27
# 6    14.39        1.87  2.45               14.6       96.0           2.50
# 7    14.06        2.15  2.61               17.6      121.0           2.60
# 8    14.83        1.64  2.17               14.0       97.0           2.80
# 9    13.86        1.35  2.27               16.0       98.0           2.98
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
# 5        3.39                  0.34             1.97             6.75  1.05
# 6        2.52                  0.30             1.98             5.25  1.02
# 7        2.51                  0.31             1.25             5.05  1.06
# 8        2.98                  0.29             1.98             5.20  1.08
# 9        3.15                  0.22             1.85             7.22  1.01
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0
# 3                          3.45   1480.0
# 4                          2.93    735.0
# 5                          2.85   1450.0
# 6                          3.58   1290.0
# 7                          3.58   1295.0
# 8                          2.85   1045.0
# 9                          3.55   1045.0
# (178, 13)

# %%
target = wine["target"]
y = pd.DataFrame(target, columns=["Class"])
print(y)
# Out:
#      Class
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 173      2
# 174      2
# 175      2
# 176      2
# 177      2
#
# [178 rows x 1 columns]

# %%
 #Постройте матрицу корреляций для всех полей X. Дайте полученному датафрейму название X_corr.
X_corr= X.loc[:,feature_names].corr()
print(X_corr)
# Out:
#                                alcohol  malic_acid       ash  \
# alcohol                       1.000000    0.094397  0.211545
# malic_acid                    0.094397    1.000000  0.164045
# ash                           0.211545    0.164045  1.000000
# alcalinity_of_ash            -0.310235    0.288500  0.443367
# magnesium                     0.270798   -0.054575  0.286587
# total_phenols                 0.289101   -0.335167  0.128980
# flavanoids                    0.236815   -0.411007  0.115077
# nonflavanoid_phenols         -0.155929    0.292977  0.186230
# proanthocyanins               0.136698   -0.220746  0.009652
# color_intensity               0.546364    0.248985  0.258887
# hue                          -0.071747   -0.561296 -0.074667
# od280/od315_of_diluted_wines  0.072343   -0.368710  0.003911
# proline                       0.643720   -0.192011  0.223626
#
#                               alcalinity_of_ash  magnesium  total_phenols  \
# alcohol                               -0.310235   0.270798       0.289101
# malic_acid                             0.288500  -0.054575      -0.335167
# ash                                    0.443367   0.286587       0.128980
# alcalinity_of_ash                      1.000000  -0.083333      -0.321113
# magnesium                             -0.083333   1.000000       0.214401
# total_phenols                         -0.321113   0.214401       1.000000
# flavanoids                            -0.351370   0.195784       0.864564
# nonflavanoid_phenols                   0.361922  -0.256294      -0.449935
# proanthocyanins                       -0.197327   0.236441       0.612413
# color_intensity                        0.018732   0.199950      -0.055136
# hue                                   -0.273955   0.055398       0.433681
# od280/od315_of_diluted_wines          -0.276769   0.066004       0.699949
# proline                               -0.440597   0.393351       0.498115
#
#                               flavanoids  nonflavanoid_phenols  \
# alcohol                         0.236815             -0.155929
# malic_acid                     -0.411007              0.292977
# ash                             0.115077              0.186230
# alcalinity_of_ash              -0.351370              0.361922
# magnesium                       0.195784             -0.256294
# total_phenols                   0.864564             -0.449935
# flavanoids                      1.000000             -0.537900
# nonflavanoid_phenols           -0.537900              1.000000
# proanthocyanins                 0.652692             -0.365845
# color_intensity                -0.172379              0.139057
# hue                             0.543479             -0.262640
# od280/od315_of_diluted_wines    0.787194             -0.503270
# proline                         0.494193             -0.311385
#
#                               proanthocyanins  color_intensity       hue  \
# alcohol                              0.136698         0.546364 -0.071747
# malic_acid                          -0.220746         0.248985 -0.561296
# ash                                  0.009652         0.258887 -0.074667
# alcalinity_of_ash                   -0.197327         0.018732 -0.273955
# magnesium                            0.236441         0.199950  0.055398
# total_phenols                        0.612413        -0.055136  0.433681
# flavanoids                           0.652692        -0.172379  0.543479
# nonflavanoid_phenols                -0.365845         0.139057 -0.262640
# proanthocyanins                      1.000000        -0.025250  0.295544
# color_intensity                     -0.025250         1.000000 -0.521813
# hue                                  0.295544        -0.521813  1.000000
# od280/od315_of_diluted_wines         0.519067        -0.428815  0.565468
# proline                              0.330417         0.316100  0.236183
#
#                               od280/od315_of_diluted_wines   proline
# alcohol                                           0.072343  0.643720
# malic_acid                                       -0.368710 -0.192011
# ash                                               0.003911  0.223626
# alcalinity_of_ash                                -0.276769 -0.440597
# magnesium                                         0.066004  0.393351
# total_phenols                                     0.699949  0.498115
# flavanoids                                        0.787194  0.494193
# nonflavanoid_phenols                             -0.503270 -0.311385
# proanthocyanins                                   0.519067  0.330417
# color_intensity                                  -0.428815  0.316100
# hue                                               0.565468  0.236183
# od280/od315_of_diluted_wines                      1.000000  0.312761
# proline                                           0.312761  1.000000

# %%
high_corr = X_corr.abs().lt(0.5)
print(high_corr)
print(type(high_corr))
high_corr.loc[high_corr['ash']=='TRUE']

#print(high_corr.keys)
#9). Создайте список high_corr из признаков, корреляция которых с полем target по абсолютному 
#значению превышает 0.5 (причем, само поле target не должно входить в этот список).
# Out:
#                               alcohol  malic_acid    ash  alcalinity_of_ash  \
# alcohol                         False        True   True               True
# malic_acid                       True       False   True               True
# ash                              True        True  False               True
# alcalinity_of_ash                True        True   True              False
# magnesium                        True        True   True               True
# total_phenols                    True        True   True               True
# flavanoids                       True        True   True               True
# nonflavanoid_phenols             True        True   True               True
# proanthocyanins                  True        True   True               True
# color_intensity                 False        True   True               True
# hue                              True       False   True               True
# od280/od315_of_diluted_wines     True        True   True               True
# proline                         False        True   True               True
#
#                               magnesium  total_phenols  flavanoids  \
# alcohol                            True           True        True
# malic_acid                         True           True        True
# ash                                True           True        True
# alcalinity_of_ash                  True           True        True
# magnesium                         False           True        True
# total_phenols                      True          False       False
# flavanoids                         True          False       False
# nonflavanoid_phenols               True           True       False
# proanthocyanins                    True          False       False
# color_intensity                    True           True        True
# hue                                True           True       False
# od280/od315_of_diluted_wines       True          False       False
# proline                            True           True        True
#
#                               nonflavanoid_phenols  proanthocyanins  \
# alcohol                                       True             True
# malic_acid                                    True             True
# ash                                           True             True
# alcalinity_of_ash                             True             True
# magnesium                                     True             True
# total_phenols                                 True            False
# flavanoids                                   False            False
# nonflavanoid_phenols                         False             True
# proanthocyanins                               True            False
# color_intensity                               True             True
# hue                                           True             True
# od280/od315_of_diluted_wines                 False            False
# proline                                       True             True
#
#                               color_intensity    hue  \
# alcohol                                 False   True
# malic_acid                               True  False
# ash                                      True   True
# alcalinity_of_ash                        True   True
# magnesium                                True   True
# total_phenols                            True   True
# flavanoids                               True  False
# nonflavanoid_phenols                     True   True
# proanthocyanins                          True   True
# color_intensity                         False  False
# hue                                     False  False
# od280/od315_of_diluted_wines             True  False
# proline                                  True   True
#
#                               od280/od315_of_diluted_wines  proline
# alcohol                                               True    False
# malic_acid                                            True     True
# ash                                                   True     True
# alcalinity_of_ash                                     True     True
# magnesium                                             True     True
# total_phenols                                        False     True
# flavanoids                                           False     True
# nonflavanoid_phenols                                 False     True
# proanthocyanins                                      False     True
# color_intensity                                       True     True
# hue                                                  False     True
# od280/od315_of_diluted_wines                         False     True
# proline                                               True    False
# <class 'pandas.core.frame.DataFrame'>
# Empty DataFrame
# Columns: [alcohol, malic_acid, ash, alcalinity_of_ash, magnesium, total_phenols, flavanoids, nonflavanoid_phenols, proanthocyanins, color_intensity, hue, od280/od315_of_diluted_wines, proline]
# Index: []
